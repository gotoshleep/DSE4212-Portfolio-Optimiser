# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
training_data = pd.read_csv("../Data prep and EDA/processed_data/training_data.csv", parse_dates=["Date"])
covid_data = pd.read_csv("../Data prep and EDA/processed_data/covid_stress_test_data.csv", parse_dates=["Date"])

# %%
# Combine (stack) them row-wise
merged_data = pd.concat([training_data, covid_data], ignore_index=True)

# Ensure 'Date' column is properly recognized as datetime
merged_data['Date'] = pd.to_datetime(merged_data['Date'])

# Sort chronologically
merged_data = merged_data.sort_values(by='Date').reset_index(drop=True)

# %%
corr_matrix_3 = merged_data.corr(numeric_only=True)

# %% Plot correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix_3,
    annot=False,         
    fmt=".2f",           # Format to 2 decimal places
    cmap='coolwarm',     
    center=0,            
    linewidths=0.5,      
    square=True          
)

plt.title('Correlation Heatmap', fontsize=14, pad=12)
plt.tight_layout()
plt.show()

corr_matrix_3
# Out:
#                            Dividends  is_in_sp500  daily_log_return  \
# Dividends                   1.000000     0.005747          0.008117
# is_in_sp500                 0.005747     1.000000         -0.006153
# daily_log_return            0.008117    -0.006153          1.000000
# daily_volume_return         0.001256    -0.000996         -0.031333
# lag_1                      -0.000131    -0.028460         -0.009498
# lag_2                      -0.000199    -0.028437         -0.007015
# lag_3                      -0.000281    -0.028377         -0.018520
# lag_4                      -0.000302    -0.028283         -0.013767
# lag_5                      -0.000190    -0.028221         -0.007849
# lag_6                      -0.000414    -0.028173         -0.011479
# lag_7                      -0.000350    -0.028085          0.005029
# lag_8                      -0.000516    -0.027962         -0.009988
# lag_9                      -0.000347    -0.027903         -0.004925
# ...
